# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('large_art_ecommerce_dataset.csv')

# %%
df.head(5)
# Out:
#   Name of Painter Subject of Painting                   Style      Medium  \
# 0            Noah            Seascape  Abstract Expressionism  Watercolor
# 1         Vincent            Abstract  Abstract Expressionism    Charcoal
# 2             Ava          Still Life                  Modern  Watercolor
# 3            Liam            Wildlife                  Cubism     Acrylic
# 4          Olivia           Landscape  Abstract Expressionism    Charcoal
#
#       Size Frame Location  Price ($)  Delivery (days)       Shipment  \
# 0  20"x30"   Yes  Chicago        459                6  Free Shipping
# 1  20"x30"    No    Miami        657                6  Free Shipping
# 2  18"x24"    No    Miami        907                7       Standard
# 3  18"x24"    No  Calgary        649                3       Standard
# 4  30"x40"   Yes    Miami        539                5  Free Shipping
#
#    Color Palette Copy or Original Print or Real Recommended Environment  \
# 0  Neutral Tones         Original         Print                 Bedroom
# 1     Cool Tones         Original         Print             Living Room
# 2     Cool Tones         Original          Real                Kid Room
# 3  Oceanic Tones         Original          Real                  Office
# 4   Earthy Tones             Copy         Print                  Office
#
#   Mood/Atmosphere Theme/Lighting Requirements Reproduction Type  \
# 0         Calming               Natural Light      Screen Print
# 1        Relaxing               Natural Light               NaN
# 2          Joyful               Natural Light               NaN
# 3      Reflective                Bright Light        Lithograph
# 4       Energetic                Bright Light        Lithograph
#
#        Target Audience
# 0    Corporate Clients
# 1    Corporate Clients
# 2    Corporate Clients
# 3  Young Professionals
# 4    Corporate Clients

# %%
df.shape
# Out:
# (2500, 18)

# %%
df.describe()
# Out:
#          Price ($)  Delivery (days)
# count  2500.000000      2500.000000
# mean    576.781200         6.482400
# std     257.831587         2.282581
# min     127.000000         3.000000
# 25%     344.000000         4.000000
# 50%     640.000000         7.000000
# 75%     813.000000         8.000000
# max     975.000000        10.000000

# %%
df.describe(include=object)
# Out:
#        Name of Painter Subject of Painting       Style      Medium     Size  \
# count             2500                2500        2500        2500     2500
# unique              11                   7           6           5        5
# top             Olivia            Wildlife  Surrealism  Watercolor  16"x20"
# freq               251                 370         434         672      514
#
#        Frame  Location       Shipment Color Palette Copy or Original  \
# count   2500      2500           2500          2500             2500
# unique     2         8              3             5                2
# top       No  Montreal  Free Shipping  Earthy Tones         Original
# freq    1285       535            834           528             1279
#
#        Print or Real Recommended Environment Mood/Atmosphere  \
# count           2500                    2500            2500
# unique             2                       5               5
# top            Print                  Office        Relaxing
# freq            1282                     515             512
#
#        Theme/Lighting Requirements Reproduction Type     Target Audience
# count                         2500              1823                2500
# unique                           3                 4                   5
# top                      Dim Light        Lithograph  Interior Designers
# freq                           840               623                 527

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name of Painter              2500 non-null   object
#  1   Subject of Painting          2500 non-null   object
#  2   Style                        2500 non-null   object
#  3   Medium                       2500 non-null   object
#  4   Size                         2500 non-null   object
#  5   Frame                        2500 non-null   object
#  6   Location                     2500 non-null   object
#  7   Price ($)                    2500 non-null   int64
#  8   Delivery (days)              2500 non-null   int64
#  9   Shipment                     2500 non-null   object
#  10  Color Palette                2500 non-null   object
#  11  Copy or Original             2500 non-null   object
#  12  Print or Real                2500 non-null   object
#  13  Recommended Environment      2500 non-null   object
#  14  Mood/Atmosphere              2500 non-null   object
#  15  Theme/Lighting Requirements  2500 non-null   object
#  16  Reproduction Type            1823 non-null   object
#  17  Target Audience              2500 non-null   object
# dtypes: int64(2), object(16)
# memory usage: 351.7+ KB

# %%
df.isnull().sum()
# Out:
# Name of Painter                  0
# Subject of Painting              0
# Style                            0
# Medium                           0
# Size                             0
# Frame                            0
# Location                         0
# Price ($)                        0
# Delivery (days)                  0
# Shipment                         0
# Color Palette                    0
# Copy or Original                 0
# Print or Real                    0
# Recommended Environment          0
# Mood/Atmosphere                  0
# Theme/Lighting Requirements      0
# Reproduction Type              677
# Target Audience                  0
# dtype: int64

# %% [markdown]
# **CLEANING**

# %%
df['Reproduction Type'] = df['Reproduction Type'].fillna('Not Applicable')

# %%
df = df.drop_duplicates()

# %%
columns_to_drop = ['Delivery (days)']
df = df.drop(columns_to_drop, axis=1)

# %%
df.shape
# Out:
# (2500, 17)

# %%
df.isnull().sum()
# Out:
# Name of Painter                0
# Subject of Painting            0
# Style                          0
# Medium                         0
# Size                           0
# Frame                          0
# Location                       0
# Price ($)                      0
# Shipment                       0
# Color Palette                  0
# Copy or Original               0
# Print or Real                  0
# Recommended Environment        0
# Mood/Atmosphere                0
# Theme/Lighting Requirements    0
# Reproduction Type              0
# Target Audience                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Price_Category'] = pd.qcut(df['Price ($)'], 
                                q=3, 
                                labels=['Low', 'Medium', 'High'])

df['Price_Category'].value_counts()
# Out:
# Price_Category
# Low       850
# High      833
# Medium    817
# Name: count, dtype: int64

# %%
df['Price_Category'].value_counts()
df['Price_Category'].value_counts(normalize=True) * 100
# Out:
# Price_Category
# Low       34.00
# High      33.32
# Medium    32.68
# Name: proportion, dtype: float64

# %%
X = df[['Name of Painter', 'Style', 'Medium', 'Size', 'Frame', 'Location', 
        'Shipment', 'Color Palette', 'Copy or Original', 'Print or Real', 
        'Recommended Environment', 'Mood/Atmosphere', 'Theme/Lighting Requirements', 
        'Reproduction Type', 'Target Audience']]
y = df['Price_Category']

# %%
df = pd.concat([X,y], axis=1)

df.head()
# Out:
#   Name of Painter                   Style      Medium     Size Frame Location  \
# 0            Noah  Abstract Expressionism  Watercolor  20"x30"   Yes  Chicago
# 1         Vincent  Abstract Expressionism    Charcoal  20"x30"    No    Miami
# 2             Ava                  Modern  Watercolor  18"x24"    No    Miami
# 3            Liam                  Cubism     Acrylic  18"x24"    No  Calgary
# 4          Olivia  Abstract Expressionism    Charcoal  30"x40"   Yes    Miami
#
#         Shipment  Color Palette Copy or Original Print or Real  \
# 0  Free Shipping  Neutral Tones         Original         Print
# 1  Free Shipping     Cool Tones         Original         Print
# 2       Standard     Cool Tones         Original          Real
# 3       Standard  Oceanic Tones         Original          Real
# 4  Free Shipping   Earthy Tones             Copy         Print
#
#   Recommended Environment Mood/Atmosphere Theme/Lighting Requirements  \
# 0                 Bedroom         Calming               Natural Light
# 1             Living Room        Relaxing               Natural Light
# 2                Kid Room          Joyful               Natural Light
# 3                  Office      Reflective                Bright Light
# 4                  Office       Energetic                Bright Light
#
#   Reproduction Type      Target Audience Price_Category
# 0      Screen Print    Corporate Clients         Medium
# 1    Not Applicable    Corporate Clients         Medium
# 2    Not Applicable    Corporate Clients           High
# 3        Lithograph  Young Professionals         Medium
# 4        Lithograph    Corporate Clients         Medium

# %%
df.shape
# Out:
# (2500, 16)

# %%
df.isnull().sum()
# Out:
# Name of Painter                0
# Style                          0
# Medium                         0
# Size                           0
# Frame                          0
# Location                       0
# Shipment                       0
# Color Palette                  0
# Copy or Original               0
# Print or Real                  0
# Recommended Environment        0
# Mood/Atmosphere                0
# Theme/Lighting Requirements    0
# Reproduction Type              0
# Target Audience                0
# Price_Category                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name of Painter              2500 non-null   object
#  1   Style                        2500 non-null   object
#  2   Medium                       2500 non-null   object
#  3   Size                         2500 non-null   object
#  4   Frame                        2500 non-null   object
#  5   Location                     2500 non-null   object
#  6   Shipment                     2500 non-null   object
#  7   Color Palette                2500 non-null   object
#  8   Copy or Original             2500 non-null   object
#  9   Print or Real                2500 non-null   object
#  10  Recommended Environment      2500 non-null   object
#  11  Mood/Atmosphere              2500 non-null   object
#  12  Theme/Lighting Requirements  2500 non-null   object
#  13  Reproduction Type            2500 non-null   object
#  14  Target Audience              2500 non-null   object
#  15  Price_Category               2500 non-null   category
# dtypes: category(1), object(15)
# memory usage: 295.7+ KB

# %%
#Encoding

from sklearn.preprocessing import LabelEncoder

# %%
X_encoded = X.copy()

# %%
for col in X_encoded.columns:
    le = LabelEncoder()
    X_encoded[col] = le.fit_transform(X_encoded[col].astype(str))

# %%
X_encoded.shape
# Out:
# (2500, 15)

# %%
X_encoded.dtypes
# Out:
# Name of Painter                int64
# Style                          int64
# Medium                         int64
# Size                           int64
# Frame                          int64
# Location                       int64
# Shipment                       int64
# Color Palette                  int64
# Copy or Original               int64
# Print or Real                  int64
# Recommended Environment        int64
# Mood/Atmosphere                int64
# Theme/Lighting Requirements    int64
# Reproduction Type              int64
# Target Audience                int64
# dtype: object

# %%
X_encoded.head()
# Out:
#    Name of Painter  Style  Medium  Size  Frame  Location  Shipment  \
# 0                7      0       4     2      1         1         1
# 1               10      0       1     2      0         3         1
# 2                0      3       4     1      0         3         2
# 3                6      1       0     1      0         0         2
# 4                8      0       1     4      1         3         1
#
#    Color Palette  Copy or Original  Print or Real  Recommended Environment  \
# 0              2                 1              0                        0
# 1              0                 1              0                        3
# 2              0                 1              1                        2
# 3              3                 1              1                        4
# 4              1                 0              0                        4
#
#    Mood/Atmosphere  Theme/Lighting Requirements  Reproduction Type  \
# 0                0                            2                  4
# 1                4                            2                  3
# 2                2                            2                  3
# 3                3                            0                  2
# 4                1                            0                  2
#
#    Target Audience
# 0                1
# 1                1
# 2                1
# 3                4
# 4                1

# %% [markdown]
# **TRAIN TEST SPLIT**

# %%
from sklearn.model_selection import train_test_split

# %%
#10%
X_train_10, X_test_10, y_train_10, y_test_10 = train_test_split(X_encoded, y, test_size = 0.10, random_state = 42)

X_train_10.shape
X_test_10.shape
# Out:
# (250, 15)

# %%
#15%
X_train_15, X_test_15, y_train_15, y_test_15 = train_test_split(X_encoded, y, test_size = 0.15, random_state = 42)

X_train_15.shape
X_test_15.shape
# Out:
# (375, 15)

# %%
#20%
X_train_20, X_test_20, y_train_20, y_test_20 = train_test_split(X_encoded, y, test_size = 0.20, random_state = 42)

X_train_20.shape
X_test_20.shape
# Out:
# (500, 15)

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics  
from sklearn.model_selection import cross_val_score

clf_RF = RandomForestClassifier(n_estimators = 100, random_state = 42)

# %%
#10%
clf_RF.fit(X_train_10, y_train_10)
y_pred_10 = clf_RF.predict(X_test_10)

accuracy_10 = metrics.accuracy_score(y_test_10, y_pred_10)
print("Accuracy: {:.2f}".format(metrics.accuracy_score(y_test_10, y_pred_10)))

cv_scores_10 = cross_val_score(clf_RF, X_train_10, y_train_10, cv=5, scoring= 'accuracy')
cv_mean_10 = cv_scores_10.mean()
cv_std_10 = cv_scores_10.std()
print(f"Individual fold scores: {[round(score, 4) for score in cv_scores_10]}")
print(f"Mean CV Score: {cv_mean_10:.4f}")
print(f"Standard Deviation: {cv_std_10:.4f}")
# Out:
# Accuracy: 0.41
# Individual fold scores: [np.float64(0.3444), np.float64(0.3311), np.float64(0.3222), np.float64(0.3067), np.float64(0.3222)]
# Mean CV Score: 0.3253
# Standard Deviation: 0.0124

# %%
#15%
clf_RF.fit(X_train_15, y_train_15)
y_pred_15 = clf_RF.predict(X_test_15)

accuracy_15 = metrics.accuracy_score(y_test_15, y_pred_15)
print("Accuracy: {:.2f}".format(metrics.accuracy_score(y_test_15, y_pred_15)))

cv_scores_15 = cross_val_score(clf_RF, X_train_15, y_train_15, cv=5, scoring= 'accuracy')
cv_mean_15 = cv_scores_15.mean()
cv_std_15 = cv_scores_15.std()
print(f"Individual fold scores: {[round(score, 4) for score in cv_scores_10]}")
print(f"Mean CV Score: {cv_mean_10:.4f}")
print(f"Standard Deviation: {cv_std_10:.4f}")
# Out:
# Accuracy: 0.38
# Individual fold scores: [np.float64(0.3444), np.float64(0.3311), np.float64(0.3222), np.float64(0.3067), np.float64(0.3222)]
# Mean CV Score: 0.3253
# Standard Deviation: 0.0124

# %%
#20%
clf_RF.fit(X_train_20, y_train_20)
y_pred_20 = clf_RF.predict(X_test_20)

accuracy_20 = metrics.accuracy_score(y_test_20, y_pred_20)
print("Accuracy: {:.2f}".format(metrics.accuracy_score(y_test_20, y_pred_20)))

cv_scores_20 = cross_val_score(clf_RF, X_train_20, y_train_20, cv=5, scoring= 'accuracy')
cv_mean_20 = cv_scores_20.mean()
cv_std_20 = cv_scores_20.std()
print(f"Individual fold scores: {[round(score, 4) for score in cv_scores_20]}")
print(f"Mean CV Score: {cv_mean_20:.4f}")
print(f"Standard Deviation: {cv_std_20:.4f}")
# Out:
# Accuracy: 0.35
# Individual fold scores: [np.float64(0.2775), np.float64(0.3475), np.float64(0.31), np.float64(0.31), np.float64(0.3175)]
# Mean CV Score: 0.3125
# Standard Deviation: 0.0223
